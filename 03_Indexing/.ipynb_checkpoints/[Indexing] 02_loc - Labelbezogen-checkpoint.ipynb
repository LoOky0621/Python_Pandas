# %% [markdown]
# # [Indexing] loc- Labelbezogen

# %%
import pandas as pd

# %%
umsatz = pd.read_csv("datengrundlage.xls")

# %% [markdown]
# ### Logik

# %%
# umsatz.loc[zeilenbezeichnung,spaltenbezeichnung]

# %% [markdown]
# ### Alle Einträge

# %%
umsatz.loc[:,:]
# Out:
#         Nr       Datum  Jahr                    Land        Stadt   Umsatz  \
# 0        1    1/1/2025  2025                Südkorea        Seoul  5534.55
# 1        2    1/2/2025  2025                Südkorea        Seoul  6284.70
# 2        3    1/3/2025  2025  Vereinigtes Königreich       London  5437.65
# 3        4    1/4/2025  2025                   China       Peking  8587.20
# 4        5    1/5/2025  2025                     USA  Los Angeles  9439.05
# ...    ...         ...   ...                     ...          ...      ...
# 1375  1376   10/7/2028  2028                Südkorea   Yangsan-si  6019.05
# 1376  1377   10/8/2028  2028                Südkorea   Yangsan-si  6482.40
# 1377  1378   10/9/2028  2028             Deutschland    Stuttgart  9192.15
# 1378  1379  10/10/2028  2028                  Mexiko      Torreón  9808.95
# 1379  1380  10/11/2028  2028                     USA   Sacramento  8303.55
#
# ...

# %% [markdown]
# ### Nur die erste Zeile (Index=0)

# %%
umsatz.loc[0,:]
# Out:
# Nr                       1
# Datum             1/1/2025
# Jahr                  2025
# Land              Südkorea
# Stadt                Seoul
# Umsatz             5534.55
# Kosten             4427.64
# Rücksendung            NaN
# Bereich          Bereich-5
# Produktgruppe        prd-3
# Logistik-Code    6-43647-1
# Kunde                 C-85
# Name: 0, dtype: object

# %% [markdown]
# ### Nur die ersten 5 Zeilen (Index=0-4)

# %%
umsatz.loc[0:4,:]
# Out:
#    Nr     Datum  Jahr                    Land        Stadt   Umsatz    Kosten  \
# 0   1  1/1/2025  2025                Südkorea        Seoul  5534.55   4427.64
# 1   2  1/2/2025  2025                Südkorea        Seoul  6284.70   7164.56
# 2   3  1/3/2025  2025  Vereinigtes Königreich       London  5437.65   6198.92
# 3   4  1/4/2025  2025                   China       Peking  8587.20   5152.32
# 4   5  1/5/2025  2025                     USA  Los Angeles  9439.05  10382.95
#
#    Rücksendung    Bereich Produktgruppe Logistik-Code  Kunde
# 0          NaN  Bereich-5         prd-3     6-43647-1   C-85
# 1          NaN  Bereich-5         prd-1     2-43647-1  C-107
# 2          NaN  Bereich-1        prd-56     7-43647-1  C-141
# 3          NaN  Bereich-2        prd-92     4-43647-1  C-124
# 4          NaN  Bereich-2        prd-85     1-43647-1   C-76

# %% [markdown]
# ### Nur ausgewählte Zeilen

# %%
umsatz.loc[[0, 4, 10, 55],:]
# Out:
#     Nr      Datum  Jahr         Land        Stadt   Umsatz    Kosten  \
# 0    1   1/1/2025  2025     Südkorea        Seoul  5534.55   4427.64
# 4    5   1/5/2025  2025          USA  Los Angeles  9439.05  10382.95
# 10  11  1/11/2025  2025          USA  Los Angeles  5246.40   3147.84
# 55  56  2/25/2025  2025  Deutschland       Berlin  7496.55   8246.20
#
#     Rücksendung    Bereich Produktgruppe Logistik-Code Kunde
# 0           NaN  Bereich-5         prd-3     6-43647-1  C-85
# 4           NaN  Bereich-2        prd-85     1-43647-1  C-76
# 10          1.0  Bereich-2        prd-97     1-43649-1  C-76
# 55          NaN  Bereich-1        prd-59     3-43656-1  C-65

# %% [markdown]
# ### Nur die Spalte "Land"

# %%
umsatz.loc[:,"Land"]
# Out:
# 0                     Südkorea
# 1                     Südkorea
# 2       Vereinigtes Königreich
# 3                        China
# 4                          USA
#                  ...
# 1375                  Südkorea
# 1376                  Südkorea
# 1377               Deutschland
# 1378                    Mexiko
# 1379                       USA
# Name: Land, Length: 1380, dtype: object

# %%
umsatz.loc[0:len(umsatz)-1,"Land"]
# Out:
# 0                     Südkorea
# 1                     Südkorea
# 2       Vereinigtes Königreich
# 3                        China
# 4                          USA
#                  ...
# 1375                  Südkorea
# 1376                  Südkorea
# 1377               Deutschland
# 1378                    Mexiko
# 1379                       USA
# Name: Land, Length: 1380, dtype: object

# %% [markdown]
# ### Nur die ersten 5 Einträge der Spalte "Land"

# %%
umsatz.loc[0:5,"Land"]
# Out:
# 0                  Südkorea
# 1                  Südkorea
# 2    Vereinigtes Königreich
# 3                     China
# 4                       USA
# 5                       USA
# Name: Land, dtype: object

# %% [markdown]
# ### Nur ausgewählte Spalten

# %%
umsatz.loc[:,["Datum", "Umsatz", "Kosten"]]
# Out:
#            Datum   Umsatz    Kosten
# 0       1/1/2025  5534.55   4427.64
# 1       1/2/2025  6284.70   7164.56
# 2       1/3/2025  5437.65   6198.92
# 3       1/4/2025  8587.20   5152.32
# 4       1/5/2025  9439.05  10382.95
# ...          ...      ...       ...
# 1375   10/7/2028  6019.05   4815.24
# 1376   10/8/2028  6482.40   5185.92
# 1377   10/9/2028  9192.15   7353.72
# 1378  10/10/2028  9808.95   7847.16
# 1379  10/11/2028  8303.55   6642.84
#
# [1380 rows x 3 columns]

# %% [markdown]
# ### Nur ausgewählte Spalten und Zeilen

# %%
umsatz.loc[[0, 4, 19, 39],["Datum", "Umsatz", "Kosten"]]
# Out:
#         Datum   Umsatz    Kosten
# 0    1/1/2025  5534.55   4427.64
# 4    1/5/2025  9439.05  10382.95
# 19  1/20/2025  9539.10   7631.28
# 39   2/9/2025  4943.55   3954.84

# %% [markdown]
# ### Neuer Index

# %%
umsatz = umsatz.set_index(['Datum'])

# %% [markdown]
# ### Indexing mit Datum

# %%
umsatz.loc["1/1/2025":"1/10/2025"]
# Out:
#            Nr  Jahr                    Land        Stadt    Umsatz    Kosten  \
# Datum
# 1/1/2025    1  2025                Südkorea        Seoul   5534.55   4427.64
# 1/2/2025    2  2025                Südkorea        Seoul   6284.70   7164.56
# 1/3/2025    3  2025  Vereinigtes Königreich       London   5437.65   6198.92
# 1/4/2025    4  2025                   China       Peking   8587.20   5152.32
# 1/5/2025    5  2025                     USA  Los Angeles   9439.05  10382.95
# 1/6/2025    6  2025                     USA  Los Angeles   5506.35   4405.08
# 1/7/2025    7  2025                Südkorea        Seoul   6589.80   7248.78
# 1/8/2025    8  2025                     USA  Los Angeles   6166.05   6782.66
# 1/9/2025    9  2025                Südkorea        Seoul  10650.60   8520.48
# 1/10/2025  10  2025                     USA  Los Angeles   8602.05   6881.64
#
#            Rücksendung    Bereich Produktgruppe Logistik-Code  Kunde
# Datum
# ...

# %%
# Out:
# Nr                       1
# Datum             1/1/2025
# Jahr                  2025
# Land              Südkorea
# Stadt                Seoul
# Umsatz             5534.55
# Kosten             4427.64
# Rücksendung            NaN
# Bereich          Bereich-5
# Produktgruppe        prd-3
# Logistik-Code    6-43647-1
# Kunde                 C-85
# Name: 0, dtype: object
