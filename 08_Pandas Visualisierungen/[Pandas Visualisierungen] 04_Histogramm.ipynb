# %% [markdown]
# # [Pandas Visualisierungen] Histogramm

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
umsatz = pd.read_csv("datengrundlage.xls")

# %% [markdown]
# ## Histogramm visualisieren

# %% [markdown]
# ### Variante 1

# %%
umsatz.dtypes
# Out:
# Nr                 int64
# Datum             object
# Jahr               int64
# Land              object
# Stadt             object
# Umsatz           float64
# Kosten           float64
# Rücksendung      float64
# Bereich           object
# Produktgruppe     object
# Logistik-Code     object
# Kunde             object
# dtype: object

# %%
umsatz.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Nr'}>,
#         <AxesSubplot:title={'center':'Jahr'}>],
#        [<AxesSubplot:title={'center':'Umsatz'}>,
#         <AxesSubplot:title={'center':'Kosten'}>],
#        [<AxesSubplot:title={'center':'Rücksendung'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
umsatz.Umsatz.hist()
# Out:
# <AxesSubplot:>

# %%
umsatz.hist(column="Umsatz")
# Out:
# array([[<AxesSubplot:title={'center':'Umsatz'}>]], dtype=object)

# %% [markdown]
# ### Variante 2

# %%
umsatz.Umsatz.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### bins-Parameter

# %%
umsatz.hist("Umsatz", bins=50, color="orange")
# Out:
# array([[<AxesSubplot:title={'center':'Umsatz'}>]], dtype=object)

# %% [markdown]
# ### Mehrere Datenreihen

# %%
umsatz[["Kosten", "Umsatz"]].plot(kind="hist", bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
umsatz.hist(column=["Kosten", "Umsatz"])
# Out:
# array([[<AxesSubplot:title={'center':'Kosten'}>,
#         <AxesSubplot:title={'center':'Umsatz'}>]], dtype=object)

# %% [markdown]
# ### Kategorische Aufteilung

# %%
umsatz.hist(column = "Umsatz", by="Land")
# Out:
# array([[<AxesSubplot:title={'center':'China'}>,
#         <AxesSubplot:title={'center':'Deutschland'}>],
#        [<AxesSubplot:title={'center':'Mexiko'}>,
#         <AxesSubplot:title={'center':'Südkorea'}>],
#        [<AxesSubplot:title={'center':'USA'}>,
#         <AxesSubplot:title={'center':'Vereinigtes Königreich'}>]],
#       dtype=object)

# %% [markdown]
# ### Filterungen

# %%
umsatz[umsatz.Land == "Deutschland"].hist(column="Umsatz", by="Stadt")
# Out:
# array([[<AxesSubplot:title={'center':'Berlin'}>,
#         <AxesSubplot:title={'center':'Bremen'}>,
#         <AxesSubplot:title={'center':'Dortmund'}>],
#        [<AxesSubplot:title={'center':'Freiburg'}>,
#         <AxesSubplot:title={'center':'Hamburg'}>,
#         <AxesSubplot:title={'center':'Hannover'}>],
#        [<AxesSubplot:title={'center':'Karlsruhe'}>,
#         <AxesSubplot:title={'center':'Leipzig'}>,
#         <AxesSubplot:title={'center':'München'}>],
#        [<AxesSubplot:title={'center':'Nürnberg'}>,
#         <AxesSubplot:title={'center':'Stuttgart'}>, <AxesSubplot:>]],
#       dtype=object)
