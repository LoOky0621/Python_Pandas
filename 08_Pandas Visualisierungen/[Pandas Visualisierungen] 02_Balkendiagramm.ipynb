# %% [markdown]
# # [Pandas Visualisierungen] Balkendiagramm

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
umsatz = pd.read_csv("datengrundlage.xls")

# %%
# umsatz

# %%
usa = umsatz[umsatz.Land == "USA"]

# %%
usa.head()
# Out:
#     Nr      Datum  Jahr Land        Stadt   Umsatz    Kosten  Rücksendung
# 4    5   1/5/2025  2025  USA  Los Angeles  9439.05  10382.95          NaN  \
# 5    6   1/6/2025  2025  USA  Los Angeles  5506.35   4405.08          NaN
# 7    8   1/8/2025  2025  USA  Los Angeles  6166.05   6782.66          NaN
# 9   10  1/10/2025  2025  USA  Los Angeles  8602.05   6881.64          NaN
# 10  11  1/11/2025  2025  USA  Los Angeles  5246.40   3147.84          1.0
#
#       Bereich Produktgruppe Logistik-Code Kunde
# 4   Bereich-2        prd-85     1-43647-1  C-76
# 5   Bereich-4        prd-35     1-43647-1  C-76
# 7   Bereich-3        prd-77     1-43648-1  C-76
# 9   Bereich-5        prd-11     1-43648-1  C-76
# 10  Bereich-2        prd-97     1-43649-1  C-76

# %%
usa.Stadt.unique()
# Out:
# array(['Los Angeles', 'Las Vegas', 'Seattle', 'Miami', 'Houston',
#        'Portland', 'Detroit', 'Denver', 'Richmond', 'San José',
#        'Honolulu', 'Orlando', 'Jackson', 'Baton Rouge', 'Fort Worth',
#        'Hartford', 'Salem', 'Montgomery', 'Topeka', 'Phoenix',
#        'Sacramento'], dtype=object)

# %%
phoenix = usa[usa.Stadt == "Phoenix"]

# %% [markdown]
# ### Variante 1

# %%
phoenix.plot.bar(x="Datum", y="Umsatz")
# Out:
# <AxesSubplot:xlabel='Datum'>

# %% [markdown]
# ### Variante 2

# %%
phoenix.plot(x="Datum", y="Umsatz", kind="bar", color="darkgreen")
# Out:
# <AxesSubplot:xlabel='Datum'>

# %% [markdown]
# ### Mehrere Balken darstellen

# %%
phoenix[["Datum", "Umsatz", "Kosten"]].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Gestapelte Darstellung

# %%
phoenix[["Datum", "Umsatz", "Kosten"]].plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Subplots

# %%
phoenix[["Datum", "Umsatz", "Kosten"]].plot(kind="bar", subplots=True, color={"orange", "darkblue"})
# Out:
# array([<AxesSubplot:title={'center':'Umsatz'}>,
#        <AxesSubplot:title={'center':'Kosten'}>], dtype=object)
