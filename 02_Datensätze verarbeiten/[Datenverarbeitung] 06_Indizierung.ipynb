# %% [markdown]
# # [Indexing] Indizes mit Pandas

# %%
import pandas as pd

# %%
umsatz = pd.read_excel("datengrundlage.xlsx", index_col = None)
umsatz.head(3)
# Out:
#    Nr      Datum  Jahr                    Land   Stadt   Umsatz    Kosten
# 0   1 2025-01-01  2025                Südkorea   Seoul  5534.55  4427.640  \
# 1   2 2025-01-02  2025                Südkorea   Seoul  6284.70  7164.558
# 2   3 2025-01-03  2025  Vereinigtes Königreich  London  5437.65  6198.921
#
#    Rücksendung    Bereich Produktgruppe Logistik-Code  Kunde
# 0        False  Bereich-5         prd-3     6-43647-1   C-85
# 1        False  Bereich-5         prd-1     2-43647-1  C-107
# 2        False  Bereich-1        prd-56     7-43647-1  C-141

# %% [markdown]
# ## Indizes

# %% [markdown]
# ### set_index: "Nr."

# %%
pd.DataFrame.index?
# Out:
# Type:        AxisProperty
# String form: <pandas._libs.properties.AxisProperty object at 0x00000229193C54C0>
# File:        c:\users\fabio\anaconda3\lib\site-packages\pandas\_libs\properties.cp39-win_amd64.pyd
# Docstring:   The index (row labels) of the DataFrame.

# %%
umsatz.index
# Out:
# RangeIndex(start=0, stop=1380, step=1)

# %%
# umsatz.set_index(["Nr"])

# %% [markdown]
# ### del: Spalten Löschen

# %%
del umsatz["Nr"]

# %%
umsatz.head(2)
# Out:
#        Datum  Jahr      Land  Stadt   Umsatz    Kosten  Rücksendung
# 0 2025-01-01  2025  Südkorea  Seoul  5534.55  4427.640        False  \
# 1 2025-01-02  2025  Südkorea  Seoul  6284.70  7164.558        False
#
#      Bereich Produktgruppe Logistik-Code  Kunde
# 0  Bereich-5         prd-3     6-43647-1   C-85
# 1  Bereich-5         prd-1     2-43647-1  C-107

# %% [markdown]
# ### set_index: "Datum"

# %%
umsatz.set_index(["Datum"])
# Out:
#             Jahr                    Land        Stadt   Umsatz     Kosten
# Datum
# 2025-01-01  2025                Südkorea        Seoul  5534.55   4427.640  \
# 2025-01-02  2025                Südkorea        Seoul  6284.70   7164.558
# 2025-01-03  2025  Vereinigtes Königreich       London  5437.65   6198.921
# 2025-01-04  2025                   China       Peking  8587.20   5152.320
# 2025-01-05  2025                     USA  Los Angeles  9439.05  10382.955
# ...          ...                     ...          ...      ...        ...
# 2028-10-07  2028                Südkorea   Yangsan-si  6019.05   4815.240
# 2028-10-08  2028                Südkorea   Yangsan-si  6482.40   5185.920
# 2028-10-09  2028             Deutschland    Stuttgart  9192.15   7353.720
# 2028-10-10  2028                  Mexiko      Torreón  9808.95   7847.160
# 2028-10-11  2028                     USA   Sacramento  8303.55   6642.840
#
#             Rücksendung    Bereich Produktgruppe Logistik-Code  Kunde
# Datum
# 2025-01-01        False  Bereich-5         prd-3     6-43647-1   C-85
# 2025-01-02        False  Bereich-5         prd-1     2-43647-1  C-107
# 2025-01-03        False  Bereich-1        prd-56     7-43647-1  C-141
# 2025-01-04        False  Bereich-2        prd-92     4-43647-1  C-124
# 2025-01-05        False  Bereich-2        prd-85     1-43647-1   C-76
# ...                 ...        ...           ...           ...    ...
# 2028-10-07        False  Bereich-3        prd-77     6-43663-1   C-85
# 2028-10-08        False  Bereich-2        prd-96     5-43655-1   C-65
# 2028-10-09        False  Bereich-1        prd-50     3-43673-1   C-65
# 2028-10-10         True  Bereich-3        prd-72     8-43659-1  C-109
# 2028-10-11        False  Bereich-2        prd-88     1-43654-2   C-76
#
# [1380 rows x 10 columns]

# %% [markdown]
# ### reset_index()

# %%
umsatz.reset_index()
# Out:
#       index      Datum  Jahr                    Land        Stadt   Umsatz
# 0         0 2025-01-01  2025                Südkorea        Seoul  5534.55  \
# 1         1 2025-01-02  2025                Südkorea        Seoul  6284.70
# 2         2 2025-01-03  2025  Vereinigtes Königreich       London  5437.65
# 3         3 2025-01-04  2025                   China       Peking  8587.20
# 4         4 2025-01-05  2025                     USA  Los Angeles  9439.05
# ...     ...        ...   ...                     ...          ...      ...
# 1375   1375 2028-10-07  2028                Südkorea   Yangsan-si  6019.05
# 1376   1376 2028-10-08  2028                Südkorea   Yangsan-si  6482.40
# 1377   1377 2028-10-09  2028             Deutschland    Stuttgart  9192.15
# 1378   1378 2028-10-10  2028                  Mexiko      Torreón  9808.95
# 1379   1379 2028-10-11  2028                     USA   Sacramento  8303.55
#
#          Kosten  Rücksendung    Bereich Produktgruppe Logistik-Code  Kunde
# 0      4427.640        False  Bereich-5         prd-3     6-43647-1   C-85
# 1      7164.558        False  Bereich-5         prd-1     2-43647-1  C-107
# 2      6198.921        False  Bereich-1        prd-56     7-43647-1  C-141
# 3      5152.320        False  Bereich-2        prd-92     4-43647-1  C-124
# 4     10382.955        False  Bereich-2        prd-85     1-43647-1   C-76
# ...         ...          ...        ...           ...           ...    ...
# 1375   4815.240        False  Bereich-3        prd-77     6-43663-1   C-85
# 1376   5185.920        False  Bereich-2        prd-96     5-43655-1   C-65
# 1377   7353.720        False  Bereich-1        prd-50     3-43673-1   C-65
# 1378   7847.160         True  Bereich-3        prd-72     8-43659-1  C-109
# 1379   6642.840        False  Bereich-2        prd-88     1-43654-2   C-76
#
# [1380 rows x 12 columns]
