# %% [markdown]
# # [Merges & Joins] OUTERJOIN

# %%
import pandas as pd

# %%
fertigung = pd.read_excel("Fertigung.xlsx")
produkt = pd.read_excel("Produkt.xlsx")

# %%
pd.merge(fertigung, produkt, on="Produkt-ID", how="outer")
# Out:
#     Produkt-ID Produktcode                  Produkt  \
# 0            1    CSX-1234          Batteriesysteme
# 1            2    GCS-4321            Kondensatoren
# 2            3    TVB-1009              Akkusysteme
# 3            4    REC-6884               Bremslicht
# 4            5    IKC-9783           Schlussleuchte
# 5            6    LMJ-2725             Blinkleuchte
# 6            7    WDX-2780  Sitzheizungskomponenten
# 7            8    HDC-4552       Motorschmiermittel
# 8            9     LAK-745            Antriebswelle
# 9           10     ISK-956            Lichtmaschine
# 10          11         NaN                      NaN
# 11          12         NaN                      NaN
# 12          13         NaN                      NaN
#
#                Produktbereich  Fertigungs-ID      Datum    Stückzahl
# 0         Electric Components            1.0 2024-03-04  8015.999851
# 1         Electric Components            2.0 2024-03-05  3357.188249
# 2         Electric Components            3.0 2024-03-06  6099.139451
# 3         Lighting Technology            4.0 2024-03-07  2113.222744
# 4         Lighting Technology            5.0 2024-03-08  2937.775980
# 5         Lighting Technology            6.0 2024-03-09  6322.981234
# 6   Heating & Climate Systems            7.0 2024-03-10  1319.032563
# 7                 Lubrication            NaN        NaT          NaN
# 8           Combustion Engine            NaN        NaT          NaN
# 9           Combustion Engine            NaN        NaT          NaN
# 10                        NaN            8.0 2024-03-11  3334.361396
# 11                        NaN            9.0 2024-03-12  2459.469720
# 12                        NaN           10.0 2024-03-13  3461.227307

# %% [markdown]
# ### Alternative Schreibweise

# %%
fertigung.merge(produkt, on="Produkt-ID", how="outer")
# Out:
#     Produkt-ID Produktcode                  Produkt  \
# 0            1    CSX-1234          Batteriesysteme
# 1            2    GCS-4321            Kondensatoren
# 2            3    TVB-1009              Akkusysteme
# 3            4    REC-6884               Bremslicht
# 4            5    IKC-9783           Schlussleuchte
# 5            6    LMJ-2725             Blinkleuchte
# 6            7    WDX-2780  Sitzheizungskomponenten
# 7            8    HDC-4552       Motorschmiermittel
# 8            9     LAK-745            Antriebswelle
# 9           10     ISK-956            Lichtmaschine
# 10          11         NaN                      NaN
# 11          12         NaN                      NaN
# 12          13         NaN                      NaN
#
#                Produktbereich  Fertigungs-ID      Datum    Stückzahl
# 0         Electric Components            1.0 2024-03-04  8015.999851
# 1         Electric Components            2.0 2024-03-05  3357.188249
# 2         Electric Components            3.0 2024-03-06  6099.139451
# 3         Lighting Technology            4.0 2024-03-07  2113.222744
# 4         Lighting Technology            5.0 2024-03-08  2937.775980
# 5         Lighting Technology            6.0 2024-03-09  6322.981234
# 6   Heating & Climate Systems            7.0 2024-03-10  1319.032563
# 7                 Lubrication            NaN        NaT          NaN
# 8           Combustion Engine            NaN        NaT          NaN
# 9           Combustion Engine            NaN        NaT          NaN
# 10                        NaN            8.0 2024-03-11  3334.361396
# 11                        NaN            9.0 2024-03-12  2459.469720
# 12                        NaN           10.0 2024-03-13  3461.227307

# %%
produkt.merge(fertigung, on="Produkt-ID", how="outer")
# Out:
#     Fertigungs-ID  Produkt-ID      Datum    Stückzahl Produktcode  \
# 0             1.0           1 2024-03-04  8015.999851    CSX-1234
# 1             2.0           2 2024-03-05  3357.188249    GCS-4321
# 2             3.0           3 2024-03-06  6099.139451    TVB-1009
# 3             4.0           4 2024-03-07  2113.222744    REC-6884
# 4             5.0           5 2024-03-08  2937.775980    IKC-9783
# 5             6.0           6 2024-03-09  6322.981234    LMJ-2725
# 6             7.0           7 2024-03-10  1319.032563    WDX-2780
# 7             8.0          11 2024-03-11  3334.361396         NaN
# 8             9.0          12 2024-03-12  2459.469720         NaN
# 9            10.0          13 2024-03-13  3461.227307         NaN
# 10            NaN           8        NaT          NaN    HDC-4552
# 11            NaN           9        NaT          NaN     LAK-745
# 12            NaN          10        NaT          NaN     ISK-956
#
#                     Produkt             Produktbereich
# 0           Batteriesysteme        Electric Components
# 1             Kondensatoren        Electric Components
# 2               Akkusysteme        Electric Components
# 3                Bremslicht        Lighting Technology
# 4            Schlussleuchte        Lighting Technology
# 5              Blinkleuchte        Lighting Technology
# 6   Sitzheizungskomponenten  Heating & Climate Systems
# 7                       NaN                        NaN
# 8                       NaN                        NaN
# 9                       NaN                        NaN
# 10       Motorschmiermittel                Lubrication
# 11            Antriebswelle          Combustion Engine
# 12            Lichtmaschine          Combustion Engine
