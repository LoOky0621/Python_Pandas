# %% [markdown]
# # [Merges & Joins] ANTIJOIN

# %%
import pandas as pd

# %%
fertigung = pd.read_excel("fertigung.xlsx")
produkt = pd.read_excel("produkt.xlsx")

# %%
fertigung
# Out:
#    Fertigungs-ID  Produkt-ID      Datum    Stückzahl
# 0              1           1 2024-03-04  8015.999851
# 1              2           2 2024-03-05  3357.188249
# 2              3           3 2024-03-06  6099.139451
# 3              4           4 2024-03-07  2113.222744
# 4              5           5 2024-03-08  2937.775980
# 5              6           6 2024-03-09  6322.981234
# 6              7           7 2024-03-10  1319.032563
# 7              8          11 2024-03-11  3334.361396
# 8              9          12 2024-03-12  2459.469720
# 9             10          13 2024-03-13  3461.227307

# %%
produkt
# Out:
#    Produkt-ID Produktcode                  Produkt             Produktbereich
# 0           1    CSX-1234          Batteriesysteme        Electric Components
# 1           2    GCS-4321            Kondensatoren        Electric Components
# 2           3    TVB-1009              Akkusysteme        Electric Components
# 3           4    REC-6884               Bremslicht        Lighting Technology
# 4           5    IKC-9783           Schlussleuchte        Lighting Technology
# 5           6    LMJ-2725             Blinkleuchte        Lighting Technology
# 6           7    WDX-2780  Sitzheizungskomponenten  Heating & Climate Systems
# 7           8    HDC-4552       Motorschmiermittel                Lubrication
# 8           9     LAK-745            Antriebswelle          Combustion Engine
# 9          10     ISK-956            Lichtmaschine          Combustion Engine

# %% [markdown]
# ### LEFTJOIN

# %%
pd.merge(fertigung, produkt, on="Produkt-ID", how="left")
# Out:
#    Fertigungs-ID  Produkt-ID      Datum    Stückzahl Produktcode
# 0              1           1 2024-03-04  8015.999851    CSX-1234  \
# 1              2           2 2024-03-05  3357.188249    GCS-4321
# 2              3           3 2024-03-06  6099.139451    TVB-1009
# 3              4           4 2024-03-07  2113.222744    REC-6884
# 4              5           5 2024-03-08  2937.775980    IKC-9783
# 5              6           6 2024-03-09  6322.981234    LMJ-2725
# 6              7           7 2024-03-10  1319.032563    WDX-2780
# 7              8          11 2024-03-11  3334.361396         NaN
# 8              9          12 2024-03-12  2459.469720         NaN
# 9             10          13 2024-03-13  3461.227307         NaN
#
#                    Produkt             Produktbereich
# 0          Batteriesysteme        Electric Components
# 1            Kondensatoren        Electric Components
# 2              Akkusysteme        Electric Components
# 3               Bremslicht        Lighting Technology
# 4           Schlussleuchte        Lighting Technology
# 5             Blinkleuchte        Lighting Technology
# 6  Sitzheizungskomponenten  Heating & Climate Systems
# 7                      NaN                        NaN
# 8                      NaN                        NaN
# 9                      NaN                        NaN

# %% [markdown]
# ### RIGHTJOIN

# %%
pd.merge(fertigung, produkt, on="Produkt-ID", how="right")
# Out:
#    Fertigungs-ID  Produkt-ID      Datum    Stückzahl Produktcode
# 0            1.0           1 2024-03-04  8015.999851    CSX-1234  \
# 1            2.0           2 2024-03-05  3357.188249    GCS-4321
# 2            3.0           3 2024-03-06  6099.139451    TVB-1009
# 3            4.0           4 2024-03-07  2113.222744    REC-6884
# 4            5.0           5 2024-03-08  2937.775980    IKC-9783
# 5            6.0           6 2024-03-09  6322.981234    LMJ-2725
# 6            7.0           7 2024-03-10  1319.032563    WDX-2780
# 7            NaN           8        NaT          NaN    HDC-4552
# 8            NaN           9        NaT          NaN     LAK-745
# 9            NaN          10        NaT          NaN     ISK-956
#
#                    Produkt             Produktbereich
# 0          Batteriesysteme        Electric Components
# 1            Kondensatoren        Electric Components
# 2              Akkusysteme        Electric Components
# 3               Bremslicht        Lighting Technology
# 4           Schlussleuchte        Lighting Technology
# 5             Blinkleuchte        Lighting Technology
# 6  Sitzheizungskomponenten  Heating & Climate Systems
# 7       Motorschmiermittel                Lubrication
# 8            Antriebswelle          Combustion Engine
# 9            Lichtmaschine          Combustion Engine

# %% [markdown]
# ## LEFT ANTI JOIN

# %%
outerjoin = pd.merge(fertigung, produkt, how="outer", on="Produkt-ID", indicator=True)

# %%
outerjoin
# Out:
#     Fertigungs-ID  Produkt-ID      Datum    Stückzahl Produktcode
# 0             1.0           1 2024-03-04  8015.999851    CSX-1234  \
# 1             2.0           2 2024-03-05  3357.188249    GCS-4321
# 2             3.0           3 2024-03-06  6099.139451    TVB-1009
# 3             4.0           4 2024-03-07  2113.222744    REC-6884
# 4             5.0           5 2024-03-08  2937.775980    IKC-9783
# 5             6.0           6 2024-03-09  6322.981234    LMJ-2725
# 6             7.0           7 2024-03-10  1319.032563    WDX-2780
# 7             8.0          11 2024-03-11  3334.361396         NaN
# 8             9.0          12 2024-03-12  2459.469720         NaN
# 9            10.0          13 2024-03-13  3461.227307         NaN
# 10            NaN           8        NaT          NaN    HDC-4552
# 11            NaN           9        NaT          NaN     LAK-745
# 12            NaN          10        NaT          NaN     ISK-956
#
#                     Produkt             Produktbereich      _merge
# 0           Batteriesysteme        Electric Components        both
# 1             Kondensatoren        Electric Components        both
# 2               Akkusysteme        Electric Components        both
# 3                Bremslicht        Lighting Technology        both
# 4            Schlussleuchte        Lighting Technology        both
# 5              Blinkleuchte        Lighting Technology        both
# 6   Sitzheizungskomponenten  Heating & Climate Systems        both
# 7                       NaN                        NaN   left_only
# 8                       NaN                        NaN   left_only
# 9                       NaN                        NaN   left_only
# 10       Motorschmiermittel                Lubrication  right_only
# 11            Antriebswelle          Combustion Engine  right_only
# 12            Lichtmaschine          Combustion Engine  right_only

# %%
outerjoin[outerjoin._merge == "left_only"].drop("_merge", axis=1)
# Out:
#    Fertigungs-ID  Produkt-ID      Datum    Stückzahl Produktcode Produkt
# 7            8.0          11 2024-03-11  3334.361396         NaN     NaN  \
# 8            9.0          12 2024-03-12  2459.469720         NaN     NaN
# 9           10.0          13 2024-03-13  3461.227307         NaN     NaN
#
#   Produktbereich
# 7            NaN
# 8            NaN
# 9            NaN

# %% [markdown]
# ## RIGHT ANTI JOIN

# %%
outerjoin[outerjoin._merge == "right_only"].drop("_merge", axis=1)
# Out:
#     Fertigungs-ID  Produkt-ID Datum  Stückzahl Produktcode
# 10            NaN           8   NaT        NaN    HDC-4552  \
# 11            NaN           9   NaT        NaN     LAK-745
# 12            NaN          10   NaT        NaN     ISK-956
#
#                Produkt     Produktbereich
# 10  Motorschmiermittel        Lubrication
# 11       Antriebswelle  Combustion Engine
# 12       Lichtmaschine  Combustion Engine
